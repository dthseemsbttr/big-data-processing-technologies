# %% [markdown]
# # Dask Delayed

# %% [markdown]
# __Автор задач: Блохин Н.В. (NVBlokhin@fa.ru)__
#
# Материалы:
# * Макрушин С.В. Лекция "Dask Delayed"
# * https://docs.dask.org/en/latest/delayed.html
# * Jesse C. Daniel. Data Science with Python and Dask.
# * https://saturncloud.io/blog/a-data-scientist-s-guide-to-lazy-evaluation-with-dask/
# * https://www.coiled.io/blog/how-to-learn-dask-in-2021

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# ![](https://i.imgur.com/AwiN8y6.png)
# ![](https://i.imgur.com/ceY6guU.png)

# %% [markdown]
# 1\. Напишите 2 функции, имитирующие CPU-bound задачу и IO-bound задачу:
#
# `cpu_task()`: генерирует 100 тыс. случайных чисел и возвращает их сумму (без использования `numpy`)
#
# `io_task()`: "спит" 0.1 сек, затем генерирует случайное число и возвращает его
#
# Замерьте время выполнения 100 последовательных вызовов каждой из этих функций. Распараллелив вычисления при помощи `dask.delayed`, сократите время выполнения. Исследуйте, как зависит время вычислений от выбранного планировщика `scheduler`.

# %%
import numpy as np
import dask.delayed as delayed
import dask.bag as db
import dask
from time import sleep
import random

# %%
def cpu_task():
    numbers = [random.randint(0, 1000) for _ in range(100_000)]
    return sum(numbers)

# %%
def io_task():
    sleep(0.1)
    return random.randint(0, 1000)

# %%
# %%time
r = [cpu_task() for _ in range(100)]
# Out:
# CPU times: total: 7.31 s
# Wall time: 7.31 s

# %%
# %%time
r = [io_task() for _ in range(100)]
# Out:
# CPU times: total: 0 ns
# Wall time: 10.9 s

# %%
cpu_task_delayed = dask.delayed(cpu_task)

# %%
# %%time
r = [cpu_task_delayed() for _ in range(100)]
r = dask.compute(r, scheduler="threading")
# Out:
# CPU times: total: 7.36 s
# Wall time: 7.35 s

# %%
# %%time
r = [cpu_task_delayed() for _ in range(100)]
r = dask.compute(r, scheduler="multiprocessing")
# Out:
# CPU times: total: 78.1 ms
# Wall time: 2.51 s

# %%
io_task_delayed = dask.delayed(io_task)

# %%
# %%time
r = [io_task_delayed() for _ in range(100)]
r = dask.compute(r, scheduler="threading")
# Out:
# CPU times: total: 15.6 ms
# Wall time: 762 ms

# %%
# %%time
r = [io_task_delayed() for _ in range(100)]
r = dask.compute(r, scheduler="multiprocessing")
# Out:
# CPU times: total: 78.1 ms
# Wall time: 1.89 s

# %% [markdown]
# ## Лабораторная работа 14

# %% [markdown]
# 1\. Напишите функцию, которая считывает файл формата xml из каталога `reviewers_full` и по данным этого файла формирует список словарей, содержащих следующие ключи: `id`, `username`, `name`, `sex`, `country`, `mail`, `registered`, `birthdate`, `name_prefix`, `country_code`. Часть из этих значений в исходном файле хранится в виде тэгов, часть - в виде атрибутов тэгов. Для конкретного человека какие-то из этих ключей могут отсутствовать.

# %%
from bs4 import BeautifulSoup

# %%
def read_xml(file):
    with open(
        file,
        "r",
        encoding="utf-8"
    ) as fp:
        xml = BeautifulSoup(fp, 'xml')
        
    reviewers = xml.find_all('user')

    users = []

    for user in reviewers:
        new_user = {}
        new_user['id'] = user.find('id').text
        new_user['username'] = user.find('username').text
        if user.find('name'):
            new_user['name'] = user.find('name').text
        if user.find('sex'):
            new_user['sex'] = user.find('sex').text
        if user.find('country'):
            new_user['country'] = user.find('country').text
        if user.find('mail'):
            new_user['mail'] = user.find('mail').text
        if user.find('registered'):
            new_user['registered'] = user.find('registered').text
        if user.find('birthdate'):
            new_user['birthdate'] = user.find('birthdate').text
        if user.get('prefix'):
            new_user['name_prefix'] = user.get('prefix')
        if user.find('country'):
            if user.find('country').get('code'):
                new_user['country_code'] = user.find('country').get('code')  

        users.append(new_user)
        
    return users

# %%
read_xml("reviewers_full/reviewers_full_0.xml")
# Out:
# [{'id': '88005',
#   'username': 'jacqueline00',
#   'name': 'Michele Lewis',
#   'mail': 'morenocharlotte@yahoo.com'},
#  {'id': '68591',
#   'username': 'daniellegomez',
#   'sex': 'F',
#   'country': 'Germany',
#   'birthdate': '2005-03-06',
#   'name_prefix': 'Dr.',
#   'country_code': 'DE'},
#  {'id': '81003',
#   'username': 'alucero',
#   'name': 'Tammy Patton',
#   'mail': 'larsenrobert@gmail.com'},
#  {'id': '61509',
#   'username': 'mcleanjacqueline',
#   'name': 'Jeremy Schmidt',
#   'sex': 'M',
#   'registered': '2017-09-21',
#   'name_prefix': 'Dr.'},
#  {'id': '74667', 'username': 'wesley96', 'registered': '2006-12-29'},
#  {'id': '43614',
#   'username': 'jeffreynelson',
#   'sex': 'F',
#   'country': 'Aruba',
#   'mail': 'laura77@hotmail.com',
#   'registered': '2019-11-19',
#   'birthdate': '1994-10-10',
#   'country_code': 'AW'},
#  {'id': '68142',
#   'username': 'sarahgarcia',
#   'name': 'Suzanne Ramirez',
#   'sex': 'F',
#   'registered': '2001-12-14'},
#  {'id': '46182',
#   'username': 'brucekennedy',
#   'sex': 'F',
#   'country': 'American Samoa',
#   'mail': 'hardyanthony@gmail.com',
#   'name_prefix': 'Mrs.',
#   'country_code': 'AS'},
#  {'id': '90638',
#   'username': 'brandonharris',
#   'name': 'Joshua Allen',
#   'sex': 'M',
#   'country': 'Azerbaijan',
#   'mail': 'travis74@gmail.com',
#   'name_prefix': 'Dr.',
#   'country_code': 'AZ'},
#  {'id': '45573',
#   'username': 'heather79',
#   'sex': 'F',
#   'country': 'Afghanistan',
#   'birthdate': '1950-03-08',
#   'country_code': 'AF'},
#  {'id': '81372',
#   'username': 'amyjimenez',
#   'name': 'Michael Hodges',
#   'sex': 'M',
#   'country': 'Martinique',
#   'name_prefix': 'Mr.',
#   'country_code': 'MQ'},
#  {'id': '25362',
#   'username': 'davidmaxwell',
#   'mail': 'steven53@gmail.com',
#   'registered': '2005-11-28',
#   'birthdate': '1996-09-07'},
#  {'id': '60619',
#   'username': 'fmartinez',
#   'sex': 'M',
#   'mail': 'rogerfischer@yahoo.com',
#   'registered': '2009-12-15',
#   'birthdate': '1968-03-17'},
#  {'id': '68765',
#   'username': 'mossdaniel',
#   'sex': 'M',
#   'birthdate': '1957-07-16',
#   'name_prefix': 'Mr.'},
#  {'id': '65569',
#   'username': 'latasha55',
#   'sex': 'F',
#   'country': 'Peru',
#   'birthdate': '1954-02-15',
#   'name_prefix': 'Dr.',
#   'country_code': 'PE'},
#  {'id': '1509',
#   'username': 'thomas07',
#   'sex': 'F',
#   'country': 'Tajikistan',
#   'registered': '2016-09-07',
#   'birthdate': '1997-03-29',
#   'name_prefix': 'Dr.',
#   'country_code': 'TJ'},
#  {'id': '94076',
#   'username': 'hannahturner',
#   'mail': 'adamrobinson@hotmail.com',
#   'registered': '2017-02-25',
#   'birthdate': '1990-04-22'},
#  {'id': '68049',
#   'username': 'anthonylambert',
#   'name': 'James Reed',
#   'sex': 'M',
#   'registered': '2003-07-24',
#   'name_prefix': 'Mr.'},
#  {'id': '7337', 'username': 'kyle76', 'sex': 'M'},
#  {'id': '81660',
#   'username': 'jpittman',
#   'name': 'Kathy Fowler',
#   'country': 'Timor-Leste',
#   'registered': '2013-03-18',
#   'birthdate': '1957-05-05',
#   'country_code': 'TL'},
#  {'id': '33320',
#   'username': 'heather62',
#   'name': 'Andrew Castro',
#   'sex': 'M',
#   'country': 'Zambia',
#   'mail': 'phogan@gmail.com',
#   'birthdate': '1998-08-13',
#   'country_code': 'ZM'},
#  {'id': '87626',
#   'username': 'lindsay04',
#   'country': 'Sudan',
#   'mail': 'alexandraandersen@yahoo.com',
#   'country_code': 'SD'},
#  {'id': '74136',
#   'username': 'bflores',
#   'name': 'Shannon Bailey',
#   'sex': 'F',
#   'country': 'Anguilla',
#   'mail': 'glovermatthew@yahoo.com',
#   'birthdate': '2020-12-14',
#   'name_prefix': 'Mrs.',
#   'country_code': 'AI'},
#  {'id': '60797',
#   'username': 'matthewsbobby',
#   'name': 'Johnny Norton',
#   'sex': 'M',
#   'country': 'Guernsey',
#   'mail': 'gregoryarroyo@hotmail.com',
#   'registered': '2009-11-08',
#   'birthdate': '1975-08-24',
#   'name_prefix': 'Dr.',
#   'country_code': 'GG'},
#  {'id': '89005',
#   'username': 'cookdanielle',
#   'name': 'Kristin Harris',
#   'country': 'Mayotte',
#   'registered': '2007-07-02',
#   'birthdate': '2011-02-11',
#   'country_code': 'YT'},
#  {'id': '25423',
#   'username': 'andrew02',
#   'name': 'Joyce Hines',
#   'sex': 'F',
#   'mail': 'richardhuynh@gmail.com',
#   'name_prefix': 'Dr.'},
#  {'id': '74677',
#   'username': 'nharmon',
#   'mail': 'parkercarmen@gmail.com',
#   'registered': '2001-05-19'},
#  {'id': '18578',
#   'username': 'michaelfranco',
#   'country': 'Comoros',
#   'mail': 'achen@gmail.com',
#   'registered': '2007-04-23',
#   'country_code': 'KM'},
#  {'id': '21392', 'username': 'gklein', 'registered': '2013-01-29'},
#  {'id': '51289',
#   'username': 'chelseaprince',
#   'mail': 'johnoliver@hotmail.com'},
#  {'id': '87484',
#   'username': 'afoley',
#   'mail': 'morrisjason@gmail.com',
#   'birthdate': '2011-10-11'},
#  {'id': '53774',
#   'username': 'rhughes',
#   'country': 'Uruguay',
#   'mail': 'crivers@gmail.com',
#   'country_code': 'UY'},
#  {'id': '88473', 'username': 'amandahartman', 'mail': 'anthony43@gmail.com'},
#  {'id': '85954',
#   'username': 'tmoore',
#   'name': 'David Moreno',
#   'country': 'Gambia',
#   'birthdate': '1953-06-24',
#   'country_code': 'GM'},
#  {'id': '52854',
#   'username': 'bryantdebra',
#   'name': 'Randy Gordon',
#   'country': 'Saint Vincent and the Grenadines',
#   'mail': 'pwalker@yahoo.com',
#   'registered': '2006-12-11',
#   'birthdate': '2016-10-22',
#   'country_code': 'VC'},
#  {'id': '70816',
#   'username': 'jdavis',
#   'name': 'James Scott',
#   'sex': 'M',
#   'mail': 'davidtaylor@hotmail.com',
#   'birthdate': '2005-03-25'},
#  {'id': '93011', 'username': 'christophersilva', 'birthdate': '2014-02-03'},
#  {'id': '29541',
#   'username': 'alexjohnson',
#   'name': 'Austin Simpson',
#   'country': 'Albania',
#   'birthdate': '1994-05-15',
#   'country_code': 'AL'},
#  {'id': '77650',
#   'username': 'lallison',
#   'sex': 'M',
#   'mail': 'brichardson@gmail.com',
#   'registered': '2010-12-15'},
#  {'id': '88456',
#   'username': 'ryan44',
#   'name': 'Frederick Davis',
#   'country': 'Montserrat',
#   'mail': 'nicholas57@gmail.com',
#   'birthdate': '1998-08-01',
#   'country_code': 'MS'},
#  {'id': '37293',
#   'username': 'brian04',
#   'country': 'Tonga',
#   'mail': 'mariowebb@yahoo.com',
#   'country_code': 'TO'},
#  {'id': '11931',
#   'username': 'katherinemartin',
#   'name': 'Mrs. Melanie Dyer',
#   'sex': 'F',
#   'country': 'Taiwan',
#   'registered': '2003-03-01',
#   'name_prefix': 'Mrs.',
#   'country_code': 'TW'},
#  {'id': '15535',
#   'username': 'sford',
#   'name': 'Bryan Rodgers',
#   'registered': '2010-04-17',
#   'birthdate': '1978-05-02'},
#  {'id': '29259',
#   'username': 'raven14',
#   'name': 'Michelle Browning',
#   'sex': 'F',
#   'country': 'Reunion',
#   'birthdate': '2007-09-03',
#   'name_prefix': 'Ms.',
#   'country_code': 'RE'},
#  {'id': '58643',
#   'username': 'gambleelijah',
#   'country': 'Iceland',
#   'mail': 'oneilljason@hotmail.com',
#   'country_code': 'IS'},
#  {'id': '5104', 'username': 'dpeck', 'sex': 'M', 'name_prefix': 'Dr.'},
#  {'id': '46050',
#   'username': 'richardnelson',
#   'name': 'Charles Garcia',
#   'country': 'Sao Tome and Principe',
#   'mail': 'suzannebrown@hotmail.com',
#   'birthdate': '1957-02-20',
#   'country_code': 'ST'},
#  {'id': '30935',
#   'username': 'kelsey71',
#   'name': 'Richard Taylor PhD',
#   'country': 'Morocco',
#   'registered': '2019-08-15',
#   'country_code': 'MA'},
#  {'id': '47147',
#   'username': 'samantha38',
#   'country': 'San Marino',
#   'mail': 'xanderson@hotmail.com',
#   'registered': '2011-12-08',
#   'country_code': 'SM'},
#  {'id': '42373',
#   'username': 'ryanwhite',
#   'name': 'John Fernandez Jr.',
#   'sex': 'M',
#   'country': 'Tunisia',
#   'registered': '2016-05-04',
#   'name_prefix': 'Mr.',
#   'country_code': 'TN'},
#  {'id': '14169', 'username': 'annerichards', 'sex': 'F'},
#  {'id': '30785',
#   'username': 'careyshannon',
#   'country': 'Comoros',
#   'registered': '2001-04-25',
#   'country_code': 'KM'},
#  {'id': '76998',
#   'username': 'ywalton',
#   'country': 'Trinidad and Tobago',
#   'birthdate': '1986-03-16',
#   'country_code': 'TT'},
#  {'id': '89270',
#   'username': 'andrew17',
#   'name': 'David Howard MD',
#   'sex': 'M',
#   'mail': 'michelle08@gmail.com'},
#  {'id': '49028',
#   'username': 'rebeccamoyer',
#   'sex': 'F',
#   'country': 'South Georgia and the South Sandwich Islands',
#   'birthdate': '1998-08-16',
#   'country_code': 'GS'},
#  {'id': '6258',
#   'username': 'brownmelissa',
#   'name': 'Daniel Martin',
#   'sex': 'M',
#   'country': 'Lithuania',
#   'birthdate': '1994-02-13',
#   'name_prefix': 'Mr.',
#   'country_code': 'LT'},
#  {'id': '86992',
#   'username': 'stephenwebb',
#   'country': "Cote d'Ivoire",
#   'mail': 'shawkevin@hotmail.com',
#   'registered': '2009-02-25',
#   'birthdate': '1989-08-12'},
#  {'id': '65849',
#   'username': 'lawrencewendy',
#   'name': 'Justin Walker',
#   'country': 'Afghanistan',
#   'mail': 'dominguezkimberly@yahoo.com',
#   'registered': '2016-04-09',
#   'country_code': 'AF'},
#  {'id': '68600', 'username': 'allenbest', 'birthdate': '2014-11-15'},
#  {'id': '51589',
#   'username': 'kristin38',
#   'mail': 'bennettlisa@gmail.com',
#   'birthdate': '1955-01-09'},
#  {'id': '88396',
#   'username': 'erin06',
#   'name': 'Mrs. Chelsea Cox',
#   'country': 'Niger',
#   'mail': 'houstoncheryl@yahoo.com',
#   'registered': '2003-11-26',
#   'birthdate': '1950-06-10',
#   'country_code': 'NE'},
#  {'id': '44559',
#   'username': 'stricklandtrevor',
#   'name': 'Kevin Hill',
#   'registered': '2001-12-14',
#   'birthdate': '1950-09-15'},
#  {'id': '27940',
#   'username': 'camachojessica',
#   'sex': 'F',
#   'country': 'Lebanon',
#   'mail': 'vasquezvirginia@yahoo.com',
#   'country_code': 'LB'},
#  {'id': '50030',
#   'username': 'lhall',
#   'name': 'Latoya Nichols',
#   'sex': 'F',
#   'birthdate': '2018-09-11'},
#  {'id': '58663',
#   'username': 'salexander',
#   'name': 'Luis Gamble',
#   'mail': 'zacharywhite@yahoo.com',
#   'registered': '2001-08-28'},
#  {'id': '80419',
#   'username': 'pattersonmargaret',
#   'name': 'Maxwell Johnson',
#   'sex': 'M',
#   'registered': '2012-09-20',
#   'name_prefix': 'Mr.'},
#  {'id': '10567',
#   'username': 'cody45',
#   'sex': 'M',
#   'mail': 'zbaker@yahoo.com',
#   'birthdate': '1957-03-23',
#   'name_prefix': 'Dr.'},
#  {'id': '69398',
#   'username': 'ycobb',
#   'country': 'Nigeria',
#   'mail': 'charles82@hotmail.com',
#   'country_code': 'NG'},
#  {'id': '51185',
#   'username': 'richardhudson',
#   'sex': 'M',
#   'mail': 'singhthomas@hotmail.com',
#   'registered': '2005-04-17',
#   'name_prefix': 'Mr.'},
#  {'id': '73264',
#   'username': 'javierday',
#   'name': 'Brenda Prince',
#   'mail': 'gregorysabrina@yahoo.com',
#   'registered': '2001-06-04',
#   'birthdate': '1968-12-29'},
#  {'id': '24564',
#   'username': 'genglish',
#   'sex': 'F',
#   'birthdate': '2020-07-04'},
#  {'id': '39755',
#   'username': 'rhall',
#   'name': 'Laura Morris',
#   'birthdate': '1998-01-02'},
#  {'id': '41596',
#   'username': 'brandonjones',
#   'name': 'James Espinoza',
#   'sex': 'M',
#   'country': 'Nauru',
#   'mail': 'mary28@hotmail.com',
#   'registered': '2011-04-10',
#   'country_code': 'NR'},
#  {'id': '82036',
#   'username': 'beckamanda',
#   'sex': 'M',
#   'country': 'United States Virgin Islands',
#   'birthdate': '2005-01-01',
#   'name_prefix': 'Mr.'},
#  {'id': '21409',
#   'username': 'lmccall',
#   'name': 'Jennifer Vazquez',
#   'country': 'Korea',
#   'mail': 'munozlisa@yahoo.com',
#   'registered': '2006-02-15'},
#  {'id': '90295',
#   'username': 'cobbashley',
#   'sex': 'F',
#   'country': 'Germany',
#   'registered': '2009-06-25',
#   'country_code': 'DE'},
#  {'id': '23250',
#   'username': 'grant90',
#   'sex': 'F',
#   'country': 'Angola',
#   'mail': 'mark38@yahoo.com',
#   'name_prefix': 'Ms.',
#   'country_code': 'AO'},
#  {'id': '84124',
#   'username': 'randyjohnson',
#   'name': 'Katherine Payne',
#   'mail': 'rossemily@yahoo.com',
#   'birthdate': '2022-02-01'},
#  {'id': '50057',
#   'username': 'angela75',
#   'sex': 'F',
#   'country': 'Eritrea',
#   'registered': '2008-08-12',
#   'birthdate': '1970-05-04',
#   'name_prefix': 'Mrs.',
#   'country_code': 'ER'},
#  {'id': '28121',
#   'username': 'ubrown',
#   'sex': 'F',
#   'mail': 'castillorebecca@gmail.com',
#   'registered': '2011-09-29',
#   'birthdate': '1956-04-12',
#   'name_prefix': 'Dr.'},
#  {'id': '17869',
#   'username': 'taylor66',
#   'name': 'Kaitlyn Willis',
#   'country': 'Saint Kitts and Nevis',
#   'birthdate': '2006-02-20',
#   'country_code': 'KN'},
#  {'id': '93116',
#   'username': 'james58',
#   'sex': 'M',
#   'country': 'Ecuador',
#   'birthdate': '2016-06-15',
#   'country_code': 'EC'},
#  {'id': '75410',
#   'username': 'anna60',
#   'name': 'Michael Smith',
#   'country': 'Isle of Man',
#   'mail': 'palmerchristopher@gmail.com',
#   'country_code': 'IM'},
#  {'id': '45800',
#   'username': 'julialewis',
#   'name': 'Amanda Torres',
#   'mail': 'robertarellano@hotmail.com'},
#  {'id': '31670',
#   'username': 'williammclean',
#   'country': 'Jordan',
#   'registered': '2011-06-19',
#   'birthdate': '2022-06-13',
#   'country_code': 'JO'},
#  {'id': '2178',
#   'username': 'danielsjudy',
#   'name': 'Cynthia Rivera',
#   'country': 'Guernsey',
#   'registered': '2017-12-30',
#   'country_code': 'GG'},
#  {'id': '29654',
#   'username': 'rodriguezmichael',
#   'name': 'Monica Meyer',
#   'registered': '2001-05-19'},
#  {'id': '2272',
#   'username': 'perezkelli',
#   'registered': '2013-07-28',
#   'birthdate': '1983-04-24'},
#  {'id': '13572',
#   'username': 'jennifer12',
#   'name': 'Patricia Harmon',
#   'birthdate': '2010-05-12'},
#  {'id': '82577',
#   'username': 'amanda50',
#   'name': 'James Martinez',
#   'country': 'Saint Barthelemy',
#   'registered': '2005-11-07',
#   'birthdate': '1984-11-29'},
#  {'id': '43889', 'username': 'chelsea24', 'birthdate': '1961-08-08'},
#  {'id': '44161',
#   'username': 'msanchez',
#   'sex': 'M',
#   'birthdate': '1970-04-30',
#   'name_prefix': 'Mr.'},
#  {'id': '52171',
#   'username': 'kathleennunez',
#   'mail': 'heatheroconnor@gmail.com',
#   'registered': '2009-03-01',
#   'birthdate': '1955-01-26'},
#  {'id': '47499',
#   'username': 'kweber',
#   'name': 'Johnny Shaw',
#   'sex': 'M',
#   'country': 'Cameroon',
#   'mail': 'randall35@yahoo.com',
#   'registered': '2005-04-01',
#   'birthdate': '1972-10-29',
#   'country_code': 'CM'},
#  {'id': '55636',
#   'username': 'christine95',
#   'sex': 'M',
#   'registered': '2010-09-27',
#   'birthdate': '1960-02-18'},
#  {'id': '43748',
#   'username': 'natalie72',
#   'name': 'Hayley Curtis',
#   'sex': 'F',
#   'registered': '2011-02-10',
#   'birthdate': '2006-12-14',
#   'name_prefix': 'Mrs.'},
#  {'id': '2423',
#   'username': 'vincentnicole',
#   'name': 'Adam Rogers',
#   'mail': 'buchanantracy@gmail.com',
#   'registered': '2005-03-03'},
#  {'id': '10562',
#   'username': 'daniel22',
#   'name': 'Jonathan Collins',
#   'registered': '2012-03-30',
#   'birthdate': '2006-08-19'},
#  {'id': '19157',
#   'username': 'buchananpatricia',
#   'name': 'Christopher Scott',
#   'sex': 'M',
#   'country': 'Latvia',
#   'mail': 'ethanrivera@hotmail.com',
#   'name_prefix': 'Mr.',
#   'country_code': 'LV'},
#  {'id': '12149',
#   'username': 'molly23',
#   'name': 'Amanda Horn',
#   'sex': 'F',
#   'country': 'Tanzania',
#   'country_code': 'TZ'},
#  {'id': '16227',
#   'username': 'pmcgrath',
#   'country': 'Fiji',
#   'birthdate': '1990-04-15',
#   'country_code': 'FJ'},
#  {'id': '22508',
#   'username': 'hudsonjacqueline',
#   'name': 'Roger Campbell',
#   'birthdate': '1961-01-06'},
#  {'id': '21541',
#   'username': 'ewilliamson',
#   'name': 'Jessica Hernandez',
#   'sex': 'F',
#   'name_prefix': 'Ms.'},
#  {'id': '22166',
#   'username': 'rodriguezlouis',
#   'sex': 'F',
#   'mail': 'wmoody@hotmail.com',
#   'registered': '2004-08-13'},
#  {'id': '30122',
#   'username': 'ashleyclarke',
#   'name': 'Nicole Prince',
#   'mail': 'jennifermathis@hotmail.com',
#   'birthdate': '2022-09-04'},
#  {'id': '74021',
#   'username': 'ibowers',
#   'sex': 'M',
#   'country': 'New Caledonia',
#   'registered': '2015-11-19',
#   'name_prefix': 'Dr.',
#   'country_code': 'NC'},
#  {'id': '22954', 'username': 'crystaleaton', 'mail': 'bbarron@gmail.com'},
#  {'id': '45927',
#   'username': 'karenneal',
#   'country': 'Western Sahara',
#   'birthdate': '1985-03-27',
#   'country_code': 'EH'},
#  {'id': '80244', 'username': 'emily21', 'mail': 'rriley@hotmail.com'},
#  {'id': '46395',
#   'username': 'harrisann',
#   'country': 'Cameroon',
#   'registered': '2001-03-27',
#   'birthdate': '1956-11-08',
#   'country_code': 'CM'},
#  {'id': '66869',
#   'username': 'jmoreno',
#   'mail': 'brian12@gmail.com',
#   'birthdate': '1955-05-08'},
#  {'id': '9425',
#   'username': 'hford',
#   'sex': 'M',
#   'country': 'American Samoa',
#   'mail': 'kristiejohnson@yahoo.com',
#   'birthdate': '1974-07-03',
#   'name_prefix': 'Mr.',
#   'country_code': 'AS'},
#  {'id': '20523',
#   'username': 'lunatara',
#   'country': 'Equatorial Guinea',
#   'registered': '2002-04-20',
#   'birthdate': '2021-05-03',
#   'country_code': 'GQ'},
#  {'id': '68459', 'username': 'paul35', 'name': 'Aimee Mccall', 'sex': 'F'},
#  {'id': '19461',
#   'username': 'michael64',
#   'name': 'Gregory Salinas',
#   'sex': 'M',
#   'country': 'Gabon',
#   'registered': '2009-01-21',
#   'birthdate': '2006-05-09',
#   'name_prefix': 'Mr.',
#   'country_code': 'GA'},
#  {'id': '20176',
#   'username': 'dana47',
#   'country': 'Netherlands',
#   'mail': 'simmonssteven@hotmail.com',
#   'registered': '2003-11-28',
#   'country_code': 'NL'},
#  {'id': '57986',
#   'username': 'jennifer43',
#   'name': 'Robert Marsh',
#   'mail': 'johnporter@yahoo.com',
#   'birthdate': '1975-09-03'},
#  {'id': '28928',
#   'username': 'mendezdiana',
#   'sex': 'F',
#   'mail': 'gmartin@gmail.com',
#   'name_prefix': 'Dr.'},
#  {'id': '70716', 'username': 'joseph03'},
#  {'id': '60361',
#   'username': 'stevenmadden',
#   'name': 'Marissa Hoffman',
#   'sex': 'F',
#   'country': 'Netherlands',
#   'registered': '2004-06-07',
#   'birthdate': '1958-08-08',
#   'country_code': 'NL'},
#  {'id': '69364',
#   'username': 'downswilliam',
#   'name': 'Natasha Roman',
#   'mail': 'wscott@yahoo.com',
#   'registered': '2016-05-10'},
#  {'id': '56387',
#   'username': 'margaret97',
#   'country': 'Egypt',
#   'mail': 'nicole16@gmail.com',
#   'registered': '2005-03-12',
#   'birthdate': '1976-10-31',
#   'country_code': 'EG'},
#  {'id': '34263',
#   'username': 'achaney',
#   'name': 'Crystal Gonzalez',
#   'sex': 'F',
#   'country': 'Mozambique',
#   'mail': 'colin41@gmail.com',
#   'registered': '2005-05-15',
#   'country_code': 'MZ'},
#  {'id': '95445',
#   'username': 'jonesanthony',
#   'sex': 'M',
#   'registered': '2011-03-09',
#   'name_prefix': 'Mr.'},
#  {'id': '8485',
#   'username': 'andrewschristopher',
#   'sex': 'M',
#   'country': 'Togo',
#   'registered': '2009-02-15',
#   'birthdate': '1969-06-03',
#   'country_code': 'TG'},
#  {'id': '81481',
#   'username': 'stuartethan',
#   'sex': 'M',
#   'country': 'Burundi',
#   'name_prefix': 'Dr.',
#   'country_code': 'BI'},
#  {'id': '49460',
#   'username': 'maypeter',
#   'name': 'Susan Adams MD',
#   'registered': '2002-01-24'},
#  {'id': '63363',
#   'username': 'lrichardson',
#   'mail': 'wray@hotmail.com',
#   'registered': '2008-08-10',
#   'birthdate': '2001-04-03'},
#  {'id': '2991',
#   'username': 'stevenhunter',
#   'country': 'China',
#   'mail': 'thomas80@hotmail.com',
#   'country_code': 'CN'},
#  {'id': '11079',
#   'username': 'danielle34',
#   'name': 'Kevin Martin',
#   'country': 'United Arab Emirates',
#   'birthdate': '1987-04-08',
#   'country_code': 'AE'},
#  {'id': '84378',
#   'username': 'hendersonteresa',
#   'sex': 'F',
#   'country': 'Moldova',
#   'registered': '2012-01-06',
#   'name_prefix': 'Mrs.'},
#  {'id': '15892',
#   'username': 'yangkristie',
#   'name': 'Michelle Wright',
#   'registered': '2003-09-12',
#   'birthdate': '1959-09-25'},
#  {'id': '6621',
#   'username': 'lopeznathan',
#   'mail': 'imartin@yahoo.com',
#   'registered': '2011-12-28'},
#  {'id': '29424',
#   'username': 'oporter',
#   'country': 'Fiji',
#   'mail': 'thomaserica@gmail.com',
#   'registered': '2012-03-30',
#   'country_code': 'FJ'},
#  {'id': '53337',
#   'username': 'carlosmorales',
#   'sex': 'F',
#   'registered': '2005-03-25',
#   'birthdate': '2017-08-11',
#   'name_prefix': 'Dr.'},
#  {'id': '41849',
#   'username': 'beltrangary',
#   'country': 'Mauritius',
#   'birthdate': '1996-08-11',
#   'country_code': 'MU'},
#  {'id': '30596',
#   'username': 'chapmandavid',
#   'mail': 'mccormickwilliam@gmail.com'},
#  {'id': '16618',
#   'username': 'jonathan22',
#   'country': 'Nepal',
#   'registered': '2001-10-28',
#   'birthdate': '1986-12-12',
#   'country_code': 'NP'},
#  {'id': '22420',
#   'username': 'wilcoxlauren',
#   'name': 'James Chan',
#   'registered': '2010-01-19',
#   'birthdate': '1982-05-17'},
#  {'id': '45287',
#   'username': 'denisedavenport',
#   'mail': 'dylanortiz@yahoo.com',
#   'birthdate': '1993-03-31'},
#  {'id': '70609',
#   'username': 'hbrown',
#   'sex': 'F',
#   'country': 'China',
#   'mail': 'teresa76@gmail.com',
#   'registered': '2009-04-18',
#   'birthdate': '1970-08-12',
#   'country_code': 'CN'},
#  {'id': '51795',
#   'username': 'laura98',
#   'name': 'Jennifer Hampton',
#   'sex': 'F',
#   'mail': 'michael39@yahoo.com',
#   'registered': '2011-08-16',
#   'birthdate': '1964-08-15',
#   'name_prefix': 'Ms.'},
#  {'id': '70848',
#   'username': 'kara48',
#   'mail': 'uchan@gmail.com',
#   'registered': '2003-06-09',
#   'birthdate': '1968-02-28'},
#  {'id': '9693',
#   'username': 'michaelleblanc',
#   'name': 'Patricia Brown',
#   'sex': 'F'},
#  {'id': '20673',
#   'username': 'lgray',
#   'sex': 'M',
#   'country': 'Kiribati',
#   'registered': '2011-01-13',
#   'name_prefix': 'Mr.',
#   'country_code': 'KI'},
#  {'id': '96074',
#   'username': 'wwilliams',
#   'name': 'Anna Hester DDS',
#   'country': 'Tunisia',
#   'registered': '2009-08-02',
#   'country_code': 'TN'},
#  {'id': '36038',
#   'username': 'strongamber',
#   'sex': 'F',
#   'country': 'Israel',
#   'mail': 'julie74@yahoo.com',
#   'birthdate': '2022-10-04',
#   'country_code': 'IL'},
#  {'id': '40756',
#   'username': 'nicolassmith',
#   'sex': 'F',
#   'country': "Lao People's Democratic Republic",
#   'registered': '2007-10-25',
#   'country_code': 'LA'},
#  {'id': '92191',
#   'username': 'nathandennis',
#   'sex': 'F',
#   'country': 'Mayotte',
#   'country_code': 'YT'},
#  {'id': '14621',
#   'username': 'edward04',
#   'sex': 'F',
#   'country': 'Vanuatu',
#   'registered': '2011-02-12',
#   'birthdate': '2020-09-02',
#   'country_code': 'VU'},
#  {'id': '10329',
#   'username': 'bowenstephen',
#   'name': 'Philip Cunningham',
#   'registered': '2013-11-09',
#   'birthdate': '1994-10-27'},
#  {'id': '9956',
#   'username': 'nrivera',
#   'name': 'Molly Marks',
#   'mail': 'morrisbecky@gmail.com'},
#  {'id': '43930',
#   'username': 'parkersuzanne',
#   'name': 'Sean Miller',
#   'sex': 'M',
#   'registered': '2013-02-12',
#   'name_prefix': 'Dr.'},
#  {'id': '40974',
#   'username': 'redwards',
#   'registered': '2015-05-09',
#   'birthdate': '1990-09-08'},
#  {'id': '87097',
#   'username': 'michaelbaker',
#   'name': 'Troy Clark',
#   'mail': 'roberto67@gmail.com',
#   'registered': '2008-10-13',
#   'birthdate': '1972-11-15'},
#  {'id': '94601',
#   'username': 'nicole12',
#   'sex': 'M',
#   'registered': '2004-10-12'},
#  {'id': '38049',
#   'username': 'andrewfreeman',
#   'name': 'Sarah Farrell',
#   'sex': 'F',
#   'country': 'Pitcairn Islands',
#   'registered': '2005-05-01',
#   'birthdate': '1996-08-31'},
#  {'id': '98860',
#   'username': 'lbenton',
#   'registered': '2015-12-07',
#   'birthdate': '1980-08-22'},
#  {'id': '52712',
#   'username': 'sellersthomas',
#   'sex': 'M',
#   'country': 'Ecuador',
#   'registered': '2001-06-11',
#   'birthdate': '1993-06-09',
#   'name_prefix': 'Dr.',
#   'country_code': 'EC'},
#  {'id': '46736',
#   'username': 'michelenewman',
#   'name': 'Ashley Smith',
#   'sex': 'F',
#   'mail': 'gaguilar@hotmail.com',
#   'registered': '2013-04-25',
#   'birthdate': '2010-02-08',
#   'name_prefix': 'Ms.'},
#  {'id': '94197',
#   'username': 'nicoleyoung',
#   'country': 'Costa Rica',
#   'mail': 'brianwilliams@gmail.com',
#   'registered': '2004-07-01',
#   'country_code': 'CR'},
#  {'id': '87608',
#   'username': 'bakerdonald',
#   'country': 'Belize',
#   'country_code': 'BZ'},
#  {'id': '82798',
#   'username': 'evanskyle',
#   'country': 'Turkey',
#   'country_code': 'TR'},
#  {'id': '39726',
#   'username': 'annamoore',
#   'sex': 'F',
#   'country': 'Czech Republic',
#   'registered': '2018-11-11',
#   'birthdate': '1980-08-02',
#   'country_code': 'CZ'},
#  {'id': '81891', 'username': 'matthew51', 'birthdate': '2011-10-26'},
#  {'id': '70717',
#   'username': 'travishendricks',
#   'sex': 'M',
#   'country': 'Sri Lanka',
#   'mail': 'hmoore@yahoo.com',
#   'registered': '2019-06-25',
#   'birthdate': '1957-11-03',
#   'country_code': 'LK'},
#  {'id': '64736',
#   'username': 'hudsonkaren',
#   'sex': 'F',
#   'country': 'Serbia',
#   'mail': 'joelrodriguez@yahoo.com',
#   'country_code': 'RS'},
#  {'id': '92355',
#   'username': 'amandaromero',
#   'name': 'Samuel Green',
#   'sex': 'M',
#   'mail': 'sarahcain@gmail.com'},
#  {'id': '70222',
#   'username': 'bethanytodd',
#   'name': 'Abigail Williams',
#   'sex': 'F',
#   'mail': 'kingmichael@hotmail.com',
#   'birthdate': '1967-04-12'},
#  {'id': '5855',
#   'username': 'leeisaac',
#   'name': 'Jason Decker',
#   'country': 'Western Sahara',
#   'registered': '2004-09-11',
#   'country_code': 'EH'},
#  {'id': '4386',
#   'username': 'peter32',
#   'mail': 'greerevelyn@gmail.com',
#   'registered': '2014-10-27',
#   'birthdate': '2022-02-04'},
#  {'id': '27310',
#   'username': 'ritamoreno',
#   'country': 'Saint Lucia',
#   'mail': 'shutchinson@yahoo.com',
#   'birthdate': '1978-05-16',
#   'country_code': 'LC'},
#  {'id': '21169',
#   'username': 'michelle00',
#   'registered': '2010-01-01',
#   'birthdate': '1967-12-12'},
#  {'id': '72612',
#   'username': 'lbarnes',
#   'name': 'Thomas Hughes',
#   'country': 'Monaco',
#   'mail': 'kowens@yahoo.com',
#   'country_code': 'MC'},
#  {'id': '28416',
#   'username': 'malloryhardy',
#   'name': 'Ashley Coleman',
#   'sex': 'F',
#   'country': "Lao People's Democratic Republic",
#   'registered': '2015-10-14',
#   'birthdate': '1971-09-06',
#   'country_code': 'LA'},
#  {'id': '65743',
#   'username': 'amanda55',
#   'name': 'Jason Kirby',
#   'sex': 'M',
#   'country': 'Latvia',
#   'registered': '2017-10-25',
#   'name_prefix': 'Mr.',
#   'country_code': 'LV'},
#  {'id': '13059',
#   'username': 'briannajones',
#   'name': 'Sarah Miller',
#   'sex': 'F',
#   'birthdate': '2005-09-30'},
#  {'id': '34510',
#   'username': 'amanda16',
#   'name': 'Mrs. Andrea Stark',
#   'country': 'Pakistan',
#   'mail': 'jeanettepham@hotmail.com',
#   'registered': '2012-05-06',
#   'birthdate': '1961-12-30',
#   'country_code': 'PK'},
#  {'id': '32735',
#   'username': 'bradfordthomas',
#   'name': 'Amy Castillo',
#   'mail': 'ericspencer@hotmail.com',
#   'birthdate': '1984-08-30'},
#  {'id': '49907', 'username': 'haynesangela', 'registered': '2018-08-19'},
#  {'id': '47661',
#   'username': 'vortiz',
#   'name': 'Rose Foley',
#   'sex': 'F',
#   'mail': 'dgreer@yahoo.com'},
#  {'id': '42970',
#   'username': 'richardslauren',
#   'mail': 'epark@hotmail.com',
#   'registered': '2005-08-12'},
#  {'id': '71138', 'username': 'danielle47', 'mail': 'blackdaniel@gmail.com'},
#  {'id': '70939', 'username': 'connormills', 'name': 'Ashley Cannon'},
#  {'id': '85824',
#   'username': 'erica51',
#   'country': 'Eritrea',
#   'birthdate': '1998-05-07',
#   'country_code': 'ER'},
#  {'id': '22578',
#   'username': 'kwatson',
#   'mail': 'maria74@yahoo.com',
#   'registered': '2008-03-27'},
#  {'id': '10088', 'username': 'ilambert'},
#  {'id': '50791',
#   'username': 'kaylapoole',
#   'name': 'Crystal Mullins',
#   'sex': 'F',
#   'country': 'Niue',
#   'birthdate': '1994-02-01',
#   'country_code': 'NU'},
#  {'id': '43885',
#   'username': 'brian91',
#   'country': 'Russian Federation',
#   'registered': '2013-09-26',
#   'birthdate': '1987-05-28'},
#  {'id': '21054',
#   'username': 'porr',
#   'name': 'Kenneth Arroyo',
#   'sex': 'M',
#   'country': 'Falkland Islands (Malvinas)',
#   'mail': 'hillsarah@hotmail.com',
#   'birthdate': '2018-03-17',
#   'name_prefix': 'Mr.',
#   'country_code': 'FK'},
#  {'id': '38622',
#   'username': 'kochmark',
#   'country': 'Syrian Arab Republic',
#   'registered': '2010-05-01',
#   'country_code': 'SY'},
#  {'id': '89729', 'username': 'angelagraham', 'name': 'Lee Smith'},
#  {'id': '69468',
#   'username': 'kellypaul',
#   'name': 'Andrew Velasquez',
#   'country': 'Isle of Man',
#   'registered': '2003-02-06',
#   'birthdate': '2022-04-30',
#   'country_code': 'IM'},
#  {'id': '94386',
#   'username': 'jennifer75',
#   'sex': 'F',
#   'registered': '2013-11-12',
#   'birthdate': '2013-03-24',
#   'name_prefix': 'Dr.'},
#  {'id': '10712',
#   'username': 'antonio87',
#   'sex': 'M',
#   'country': 'Jordan',
#   'mail': 'obaker@yahoo.com',
#   'birthdate': '1967-03-11',
#   'country_code': 'JO'},
#  {'id': '29678',
#   'username': 'amanda45',
#   'country': 'Myanmar',
#   'birthdate': '1966-12-13',
#   'country_code': 'MM'},
#  {'id': '80653',
#   'username': 'katrina00',
#   'name': 'Terri Lindsey',
#   'country': 'Antarctica (the territory South of 60 deg S)',
#   'mail': 'steelegeorge@hotmail.com',
#   'registered': '2006-06-23',
#   'birthdate': '1966-11-10'},
#  {'id': '26341',
#   'username': 'darrylwalker',
#   'name': 'Nicholas Morris',
#   'sex': 'M',
#   'country': 'Western Sahara',
#   'mail': 'sarah64@yahoo.com',
#   'registered': '2004-07-17',
#   'country_code': 'EH'},
#  {'id': '87304',
#   'username': 'djohnson',
#   'country': 'Thailand',
#   'mail': 'rmorris@yahoo.com',
#   'country_code': 'TH'},
#  {'id': '17351',
#   'username': 'laurie43',
#   'sex': 'F',
#   'country': 'Wallis and Futuna',
#   'mail': 'deborah22@gmail.com',
#   'registered': '2001-04-23',
#   'country_code': 'WF'},
#  {'id': '71756', 'username': 'erik31', 'sex': 'F', 'birthdate': '1957-02-09'},
#  {'id': '8491',
#   'username': 'warrendylan',
#   'sex': 'M',
#   'mail': 'nwatts@hotmail.com',
#   'registered': '2019-03-21',
#   'birthdate': '1978-04-16',
#   'name_prefix': 'Mr.'},
#  {'id': '7953',
#   'username': 'jyoung',
#   'name': 'Dennis Harris',
#   'country': 'Turkey',
#   'mail': 'vmcmahon@yahoo.com',
#   'birthdate': '2014-11-10',
#   'country_code': 'TR'},
#  {'id': '8673',
#   'username': 'msmith',
#   'sex': 'M',
#   'country': 'Kuwait',
#   'registered': '2001-03-13',
#   'birthdate': '1997-11-28',
#   'name_prefix': 'Mr.',
#   'country_code': 'KW'},
#  {'id': '30092', 'username': 'neil23', 'birthdate': '1959-07-12'},
#  {'id': '2738',
#   'username': 'gmay',
#   'name': 'Eric Ford',
#   'sex': 'M',
#   'country': 'Croatia',
#   'registered': '2003-08-10',
#   'name_prefix': 'Mr.',
#   'country_code': 'HR'},
#  {'id': '11797',
#   'username': 'albertpowers',
#   'sex': 'F',
#   'birthdate': '1998-09-04'},
#  {'id': '18354',
#   'username': 'djohnson',
#   'registered': '2001-09-15',
#   'birthdate': '2016-02-14'},
#  {'id': '55694',
#   'username': 'fordlindsay',
#   'registered': '2012-01-11',
#   'birthdate': '1972-11-20'},
#  {'id': '13210',
#   'username': 'jonathanthompson',
#   'registered': '2011-03-04',
#   'birthdate': '2004-05-02'},
#  {'id': '80486',
#   'username': 'amy72',
#   'name': 'Steven Mcdonald',
#   'sex': 'M',
#   'birthdate': '1961-09-10',
#   'name_prefix': 'Dr.'},
#  {'id': '27786',
#   'username': 'perrytrevor',
#   'name': 'Randy Flowers',
#   'country': 'Israel',
#   'mail': 'ronald88@yahoo.com',
#   'registered': '2007-01-28',
#   'birthdate': '2010-03-20',
#   'country_code': 'IL'},
#  {'id': '62328',
#   'username': 'vanessa80',
#   'name': 'Megan Strickland',
#   'sex': 'F',
#   'registered': '2017-11-27',
#   'birthdate': '1991-09-20',
#   'name_prefix': 'Mrs.'},
#  {'id': '18404',
#   'username': 'xrussell',
#   'name': 'Lindsey Stewart',
#   'sex': 'F',
#   'mail': 'andrew31@yahoo.com',
#   'registered': '2014-10-04'},
#  {'id': '62518',
#   'username': 'pamela54',
#   'sex': 'F',
#   'country': 'Thailand',
#   'mail': 'scottrowland@yahoo.com',
#   'registered': '2015-11-21',
#   'name_prefix': 'Mrs.',
#   'country_code': 'TH'},
#  {'id': '41192',
#   'username': 'lucas13',
#   'name': 'William Cooper',
#   'country': 'Northern Mariana Islands',
#   'mail': 'susan50@hotmail.com',
#   'country_code': 'MP'},
#  {'id': '90221',
#   'username': 'leah81',
#   'sex': 'F',
#   'country': 'Suriname',
#   'birthdate': '1990-07-05',
#   'name_prefix': 'Mrs.',
#   'country_code': 'SR'},
#  {'id': '96262',
#   'username': 'dgraham',
#   'country': 'Djibouti',
#   'birthdate': '1979-10-29',
#   'country_code': 'DJ'},
#  {'id': '82873',
#   'username': 'mark61',
#   'sex': 'F',
#   'country': 'Bermuda',
#   'mail': 'markhunt@yahoo.com',
#   'registered': '2016-06-28',
#   'name_prefix': 'Miss',
#   'country_code': 'BM'},
#  {'id': '41566',
#   'username': 'waltonmichael',
#   'name': 'Brittney Smith',
#   'sex': 'F',
#   'registered': '2014-02-04',
#   'birthdate': '1985-01-23',
#   'name_prefix': 'Ms.'},
#  {'id': '33148',
#   'username': 'april97',
#   'sex': 'F',
#   'country': 'Croatia',
#   'mail': 'kosborn@yahoo.com',
#   'country_code': 'HR'},
#  {'id': '33322',
#   'username': 'kimberly52',
#   'registered': '2010-07-16',
#   'birthdate': '2005-07-29'},
#  {'id': '4638',
#   'username': 'jill33',
#   'sex': 'M',
#   'country': 'Cameroon',
#   'mail': 'latoyaburns@yahoo.com',
#   'birthdate': '1998-06-19',
#   'country_code': 'CM'},
#  {'id': '53566',
#   'username': 'mccannkimberly',
#   'name': 'Michael Middleton',
#   'mail': 'ijones@hotmail.com',
#   'registered': '2012-05-10',
#   'birthdate': '1963-08-09'},
#  {'id': '38181', 'username': 'stacysanders'},
#  {'id': '17344', 'username': 'vmendoza', 'mail': 'maustin@yahoo.com'},
#  {'id': '51104',
#   'username': 'ymathis',
#   'sex': 'M',
#   'country': 'Sao Tome and Principe',
#   'mail': 'jenniferhenderson@gmail.com',
#   'birthdate': '2017-04-24',
#   'country_code': 'ST'},
#  {'id': '34651',
#   'username': 'gregory59',
#   'sex': 'M',
#   'mail': 'jarvisariel@gmail.com',
#   'name_prefix': 'Mr.'},
#  {'id': '22325',
#   'username': 'vosborne',
#   'sex': 'M',
#   'mail': 'yorkjessica@hotmail.com',
#   'registered': '2010-09-07',
#   'name_prefix': 'Mr.'},
#  {'id': '64611',
#   'username': 'ashley91',
#   'sex': 'F',
#   'birthdate': '1965-02-20',
#   'name_prefix': 'Mrs.'},
#  {'id': '6793',
#   'username': 'wadams',
#   'name': 'Jennifer Riddle',
#   'registered': '2011-08-10',
#   'birthdate': '1973-09-20'},
#  {'id': '25212',
#   'username': 'ywilliams',
#   'sex': 'M',
#   'mail': 'edward91@yahoo.com',
#   'registered': '2008-01-22',
#   'birthdate': '1982-10-05'},
#  {'id': '72750',
#   'username': 'mileslinda',
#   'name': 'Hunter Brown',
#   'mail': 'hurleybenjamin@yahoo.com',
#   'registered': '2004-01-19'},
#  {'id': '57481',
#   'username': 'robert57',
#   'sex': 'F',
#   'country': 'San Marino',
#   'registered': '2014-02-15',
#   'name_prefix': 'Mrs.',
#   'country_code': 'SM'},
#  {'id': '8761',
#   'username': 'taylormark',
#   'name': 'Sandra Hutchinson',
#   'sex': 'F',
#   'country': 'Cambodia',
#   'registered': '2018-05-10',
#   'birthdate': '1970-02-05',
#   'name_prefix': 'Miss',
#   'country_code': 'KH'},
#  {'id': '82031',
#   'username': 'sandraburgess',
#   'name': 'Jerry Ellison',
#   'country': 'Cook Islands',
#   'mail': 'xcarroll@yahoo.com',
#   'birthdate': '2018-02-16',
#   'country_code': 'CK'},
#  {'id': '34874',
#   'username': 'nsmith',
#   'name': 'John Brown',
#   'sex': 'M',
#   'mail': 'john39@yahoo.com'},
#  {'id': '52843',
#   'username': 'hbennett',
#   'name': 'Kevin Perez',
#   'sex': 'M',
#   'mail': 'porterdiane@hotmail.com',
#   'registered': '2007-09-09',
#   'birthdate': '1979-02-06'},
#  {'id': '13820',
#   'username': 'oyoung',
#   'sex': 'M',
#   'country': 'San Marino',
#   'registered': '2011-05-06',
#   'country_code': 'SM'},
#  {'id': '93908',
#   'username': 'shenry',
#   'name': 'Zachary Wallace',
#   'country': 'Micronesia',
#   'birthdate': '1969-04-25'},
#  {'id': '71963',
#   'username': 'melissagay',
#   'country': 'Cayman Islands',
#   'mail': 'gregoryflowers@yahoo.com',
#   'birthdate': '1969-02-11',
#   'country_code': 'KY'},
#  {'id': '60063',
#   'username': 'alexismathis',
#   'mail': 'robinsonallen@yahoo.com',
#   'registered': '2017-07-10',
#   'birthdate': '1960-01-16'},
#  {'id': '39267',
#   'username': 'qharris',
#   'mail': 'ricardo61@hotmail.com',
#   'registered': '2008-10-02'},
#  {'id': '55280',
#   'username': 'laurenhayes',
#   'mail': 'cassandrastephens@hotmail.com'},
#  {'id': '73495',
#   'username': 'matthewjohnson',
#   'sex': 'M',
#   'country': 'Seychelles',
#   'birthdate': '1964-11-19',
#   'name_prefix': 'Dr.',
#   'country_code': 'SC'},
#  {'id': '1003',
#   'username': 'diazlisa',
#   'sex': 'M',
#   'country': 'Taiwan',
#   'birthdate': '2014-10-16',
#   'country_code': 'TW'},
#  {'id': '92618',
#   'username': 'xmyers',
#   'name': 'Nicole Wilson',
#   'registered': '2009-11-05',
#   'birthdate': '1998-02-22'},
#  {'id': '471',
#   'username': 'vmcconnell',
#   'mail': 'ricejack@yahoo.com',
#   'registered': '2008-12-19'},
#  {'id': '20039', 'username': 'alexandra25', 'birthdate': '1953-07-04'},
#  {'id': '57422',
#   'username': 'woodswilliam',
#   'sex': 'F',
#   'country': 'Paraguay',
#   'birthdate': '2004-04-23',
#   'country_code': 'PY'},
#  {'id': '79145',
#   'username': 'gina38',
#   'name': 'Amber Cole',
#   'country': 'Botswana',
#   'mail': 'jessicagriffin@yahoo.com',
#   'country_code': 'BW'},
#  {'id': '55319', 'username': 'fernandoobrien', 'birthdate': '2007-02-01'},
#  {'id': '64191',
#   'username': 'uoconnell',
#   'name': 'Daniel Gray',
#   'sex': 'M',
#   'country': 'Bahrain',
#   'mail': 'candice18@yahoo.com',
#   'country_code': 'BH'},
#  {'id': '20610', 'username': 'jwelch', 'name': 'Andrea Mckinney'},
#  {'id': '20785', 'username': 'jli', 'name': 'Carol Hartman', 'sex': 'F'},
#  {'id': '18544',
#   'username': 'shellymarshall',
#   'country': 'Timor-Leste',
#   'country_code': 'TL'},
#  {'id': '90630',
#   'username': 'christopherhernandez',
#   'country': 'Palau',
#   'birthdate': '2014-12-25',
#   'country_code': 'PW'},
#  {'id': '6313', 'username': 'brandyschneider', 'name': 'Jamie Dougherty'},
#  {'id': '7147',
#   'username': 'david52',
#   'name': 'Patrick Sanchez',
#   'country': 'Bermuda',
#   'registered': '2013-06-30',
#   'birthdate': '1977-07-16',
#   'country_code': 'BM'},
#  {'id': '95092',
#   'username': 'vanessa87',
#   'name': 'Rebecca Robbins',
#   'birthdate': '1957-02-19'},
#  {'id': '21395',
#   'username': 'dorothy77',
#   'name': 'Marc Cooper',
#   'sex': 'M',
#   'country': 'Venezuela',
#   'mail': 'valenzuelamichael@yahoo.com',
#   'birthdate': '1990-03-11',
#   'country_code': 'VE'},
#  {'id': '11378',
#   'username': 'harveykelsey',
#   'country': 'Hungary',
#   'registered': '2004-10-28',
#   'country_code': 'HU'},
#  {'id': '87942',
#   'username': 'johnsonmichelle',
#   'sex': 'F',
#   'country': 'Sweden',
#   'mail': 'otrujillo@hotmail.com',
#   'birthdate': '1983-09-24',
#   'name_prefix': 'Dr.',
#   'country_code': 'SE'},
#  {'id': '20564',
#   'username': 'nwolf',
#   'name': 'Jennifer Cabrera',
#   'country': 'Suriname',
#   'registered': '2004-05-03',
#   'birthdate': '1956-12-07',
#   'country_code': 'SR'},
#  {'id': '68218',
#   'username': 'xperry',
#   'country': 'Tokelau',
#   'mail': 'joseph41@hotmail.com',
#   'registered': '2005-09-12',
#   'birthdate': '1978-01-23',
#   'country_code': 'TK'},
#  {'id': '22933', 'username': 'levans', 'birthdate': '1959-12-31'},
#  {'id': '60705',
#   'username': 'christopherjoseph',
#   'name': 'Stephanie Harris',
#   'mail': 'kochsean@hotmail.com'},
#  {'id': '56917',
#   'username': 'ssmith',
#   'sex': 'M',
#   'mail': 'gsingleton@hotmail.com',
#   'name_prefix': 'Mr.'},
#  {'id': '82366',
#   'username': 'michaelbradford',
#   'registered': '2008-08-01',
#   'birthdate': '1954-09-18'},
#  {'id': '4885',
#   'username': 'jamesingram',
#   'name': 'Kristen Schultz',
#   'sex': 'F',
#   'country': 'Macao',
#   'registered': '2005-09-18',
#   'country_code': 'MO'},
#  {'id': '53582',
#   'username': 'ecobb',
#   'sex': 'F',
#   'country': 'Wallis and Futuna',
#   'mail': 'williammiller@gmail.com',
#   'registered': '2002-03-18',
#   'name_prefix': 'Mrs.',
#   'country_code': 'WF'},
#  {'id': '57594',
#   'username': 'huynhchristopher',
#   'name': 'Christopher Nelson',
#   'country': 'Philippines',
#   'registered': '2019-03-10',
#   'country_code': 'PH'},
#  {'id': '69402',
#   'username': 'kristengraham',
#   'country': 'Burkina Faso',
#   'country_code': 'BF'},
#  {'id': '96073',
#   'username': 'cindy11',
#   'sex': 'F',
#   'registered': '2011-05-19',
#   'name_prefix': 'Dr.'},
#  {'id': '67201',
#   'username': 'sanchezjacqueline',
#   'name': 'Sarah Abbott',
#   'sex': 'F',
#   'country': 'Sao Tome and Principe',
#   'mail': 'scottnguyen@hotmail.com',
#   'registered': '2012-06-17',
#   'birthdate': '1954-09-25',
#   'name_prefix': 'Mrs.',
#   'country_code': 'ST'},
#  {'id': '34808', 'username': 'steven71', 'birthdate': '1971-08-28'},
#  {'id': '41936', 'username': 'pscott', 'registered': '2015-06-11'},
#  {'id': '58027', 'username': 'castillodouglas', 'birthdate': '1976-03-03'},
#  {'id': '60237',
#   'username': 'jorgeallen',
#   'mail': 'zacharysalazar@gmail.com',
#   'registered': '2017-11-03'},
#  {'id': '689',
#   'username': 'millerjoseph',
#   'name': 'William Griffin',
#   'sex': 'M',
#   'mail': 'allendawn@gmail.com',
#   'registered': '2002-01-24',
#   'birthdate': '1998-03-08',
#   'name_prefix': 'Mr.'},
#  {'id': '20017',
#   'username': 'lori61',
#   'sex': 'F',
#   'country': 'Saint Kitts and Nevis',
#   'mail': 'cynthia30@yahoo.com',
#   'birthdate': '1979-11-28',
#   'country_code': 'KN'},
#  {'id': '66365',
#   'username': 'kimberly68',
#   'name': 'Denise Jones',
#   'registered': '2006-07-27',
#   'birthdate': '2013-10-13'},
#  {'id': '65859',
#   'username': 'burkejoshua',
#   'sex': 'M',
#   'mail': 'iodonnell@gmail.com',
#   'birthdate': '1995-10-07'},
#  {'id': '14761',
#   'username': 'rodriguezrebecca',
#   'sex': 'M',
#   'mail': 'brenda92@yahoo.com'},
#  {'id': '18439',
#   'username': 'stewartlaura',
#   'sex': 'F',
#   'country': 'Saudi Arabia',
#   'mail': 'lynchchristie@hotmail.com',
#   'birthdate': '1964-12-05',
#   'name_prefix': 'Mrs.',
#   'country_code': 'SA'},
#  {'id': '50742',
#   'username': 'simmonslisa',
#   'country': 'Dominica',
#   'mail': 'ibrown@hotmail.com',
#   'registered': '2013-10-29',
#   'country_code': 'DM'},
#  {'id': '81600',
#   'username': 'odomchelsey',
#   'name': 'Angela Martin',
#   'sex': 'F',
#   'country': 'Austria',
#   'name_prefix': 'Miss',
#   'country_code': 'AT'},
#  {'id': '36038',
#   'username': 'natalieglenn',
#   'name': 'Michelle Martinez',
#   'sex': 'F',
#   'registered': '2006-03-08',
#   'birthdate': '1968-02-27',
#   'name_prefix': 'Mrs.'},
#  {'id': '21908',
#   'username': 'sscott',
#   'name': 'Robert Andrade',
#   'country': 'Cocos (Keeling) Islands',
#   'country_code': 'CC'},
#  {'id': '74637', 'username': 'yduncan', 'name': 'Tiffany Johnston'},
#  {'id': '81549',
#   'username': 'nthompson',
#   'name': 'Rhonda Conrad',
#   'sex': 'F',
#   'birthdate': '2001-05-11'},
#  {'id': '49184',
#   'username': 'nmendoza',
#   'sex': 'F',
#   'country': 'French Southern Territories',
#   'registered': '2005-08-14',
#   'country_code': 'TF'},
#  {'id': '72362',
#   'username': 'glewis',
#   'sex': 'F',
#   'country': 'Palestinian Territory',
#   'mail': 'rangelshawn@gmail.com',
#   'registered': '2001-02-01',
#   'birthdate': '1994-10-18',
#   'name_prefix': 'Ms.'},
#  {'id': '99110',
#   'username': 'jennifer42',
#   'name': 'Kristine Raymond',
#   'country': 'Western Sahara',
#   'registered': '2007-06-03',
#   'country_code': 'EH'},
#  {'id': '31531',
#   'username': 'brownjessica',
#   'sex': 'F',
#   'country': 'Bangladesh',
#   'mail': 'douglas65@gmail.com',
#   'birthdate': '1973-10-25',
#   'name_prefix': 'Mrs.',
#   'country_code': 'BD'},
#  {'id': '22168', 'username': 'martinezgeorge'},
#  {'id': '29680',
#   'username': 'christopherdawson',
#   'country': 'Denmark',
#   'country_code': 'DK'},
#  {'id': '70902',
#   'username': 'jennifer87',
#   'sex': 'F',
#   'registered': '2016-11-15',
#   'birthdate': '2008-07-28'},
#  {'id': '31001',
#   'username': 'cassandra18',
#   'name': 'Shawn Lin',
#   'registered': '2010-08-05'},
#  {'id': '78529',
#   'username': 'cunninghamcheyenne',
#   'country': 'Syrian Arab Republic',
#   'country_code': 'SY'},
#  {'id': '89709',
#   'username': 'stevenrowe',
#   'name': 'James Owen',
#   'country': 'San Marino',
#   'registered': '2015-06-25',
#   'country_code': 'SM'},
#  {'id': '54384',
#   'username': 'bwolfe',
#   'mail': 'brandy41@yahoo.com',
#   'birthdate': '1996-03-17'},
#  {'id': '57498',
#   'username': 'derek64',
#   'name': 'Bradley Foster',
#   'country': 'Sao Tome and Principe',
#   'country_code': 'ST'},
#  {'id': '16527',
#   'username': 'breanna50',
#   'sex': 'F',
#   'mail': 'jamesallison@hotmail.com'},
#  {'id': '21407',
#   'username': 'nmorgan',
#   'name': 'James Berry',
#   'country': 'Kiribati',
#   'birthdate': '1963-08-07',
#   'country_code': 'KI'},
#  {'id': '54880',
#   'username': 'stephen47',
#   'country': 'Gibraltar',
#   'registered': '2016-07-19',
#   'birthdate': '1954-07-24',
#   'country_code': 'GI'},
#  {'id': '27964', 'username': 'elizabethmartinez', 'sex': 'F'},
#  {'id': '94008',
#   'username': 'stephanietownsend',
#   'name': 'Brandon Morris',
#   'country': 'Saint Vincent and the Grenadines',
#   'mail': 'wangeric@gmail.com',
#   'birthdate': '1971-08-22',
#   'country_code': 'VC'},
#  {'id': '84240',
#   'username': 'rrobertson',
#   'country': 'Guam',
#   'registered': '2001-01-21',
#   'birthdate': '2001-10-13',
#   'country_code': 'GU'},
#  {'id': '31005',
#   'username': 'johnrichards',
#   'sex': 'F',
#   'registered': '2001-09-22',
#   'name_prefix': 'Mrs.'},
#  {'id': '46848',
#   'username': 'roy50',
#   'name': 'Linda Stark',
#   'country': 'Martinique',
#   'country_code': 'MQ'},
#  {'id': '25329',
#   'username': 'jacob80',
#   'name': 'Kathy Scott',
#   'country': 'Aruba',
#   'mail': 'usummers@yahoo.com',
#   'registered': '2015-10-06',
#   'country_code': 'AW'},
#  {'id': '56917',
#   'username': 'brownjason',
#   'name': 'Juan Morrow',
#   'country': 'Pitcairn Islands',
#   'mail': 'krivera@hotmail.com'},
#  {'id': '98445',
#   'username': 'jacksonamber',
#   'name': 'Grant Taylor',
#   'sex': 'M',
#   'country': 'French Polynesia',
#   'mail': 'qcunningham@hotmail.com',
#   'name_prefix': 'Mr.',
#   'country_code': 'PF'},
#  {'id': '48084',
#   'username': 'debra92',
#   'country': 'Taiwan',
#   'registered': '2011-06-23',
#   'birthdate': '2005-01-29',
#   'country_code': 'TW'},
#  {'id': '91582',
#   'username': 'tvega',
#   'country': 'Cambodia',
#   'birthdate': '1970-11-16',
#   'country_code': 'KH'},
#  {'id': '28959',
#   'username': 'wwalker',
#   'name': 'Laura Newman',
#   'country': 'Dominican Republic',
#   'registered': '2006-09-02',
#   'birthdate': '2002-06-14',
#   'country_code': 'DO'},
#  {'id': '18050',
#   'username': 'hudsonbrittany',
#   'country': 'Mayotte',
#   'country_code': 'YT'},
#  {'id': '31080',
#   'username': 'chaneydominic',
#   'sex': 'F',
#   'mail': 'uroth@yahoo.com',
#   'registered': '2014-06-07',
#   'name_prefix': 'Dr.'},
#  {'id': '67395',
#   'username': 'ryanromero',
#   'mail': 'elandry@yahoo.com',
#   'registered': '2019-07-05'},
#  {'id': '60976',
#   'username': 'carolgonzalez',
#   'sex': 'M',
#   'country': 'Sao Tome and Principe',
#   'mail': 'glennjulie@hotmail.com',
#   'registered': '2016-03-02',
#   'country_code': 'ST'},
#  {'id': '81416',
#   'username': 'normangary',
#   'country': 'Uruguay',
#   'mail': 'millerheather@hotmail.com',
#   'birthdate': '2019-10-18',
#   'country_code': 'UY'},
#  {'id': '50813',
#   'username': 'frenchlori',
#   'name': 'Cassandra Gallagher',
#   'sex': 'F',
#   'mail': 'kevinrogers@yahoo.com',
#   'registered': '2003-01-31',
#   'birthdate': '1994-02-26',
#   'name_prefix': 'Mrs.'},
#  {'id': '64204',
#   'username': 'sheatimothy',
#   'country': 'Comoros',
#   'registered': '2010-05-05',
#   'birthdate': '2012-09-22',
#   'country_code': 'KM'},
#  {'id': '46357',
#   'username': 'hobbskayla',
#   'name': 'Connie Porter',
#   'sex': 'F',
#   'country': 'Turkmenistan',
#   'mail': 'tlopez@hotmail.com',
#   'country_code': 'TM'},
#  {'id': '20824',
#   'username': 'lynn86',
#   'name': 'Angela Burns',
#   'sex': 'F',
#   'country': 'Congo',
#   'mail': 'mccormickmelissa@gmail.com',
#   'registered': '2002-09-26',
#   'name_prefix': 'Ms.'},
#  {'id': '17502',
#   'username': 'vhunter',
#   'name': 'David Harris',
#   'country': 'Afghanistan',
#   'mail': 'upatel@yahoo.com',
#   'registered': '2011-05-17',
#   'country_code': 'AF'},
#  {'id': '54493',
#   'username': 'reedjuan',
#   'sex': 'M',
#   'country': 'Timor-Leste',
#   'birthdate': '1974-12-22',
#   'name_prefix': 'Mr.',
#   'country_code': 'TL'},
#  {'id': '61158',
#   'username': 'jasonjennings',
#   'sex': 'F',
#   'registered': '2012-04-21',
#   'birthdate': '1978-04-11'},
#  {'id': '26931',
#   'username': 'dominiquegarcia',
#   'sex': 'M',
#   'country': 'Brunei Darussalam',
#   'mail': 'mgarcia@hotmail.com',
#   'registered': '2017-03-12',
#   'birthdate': '1975-10-10',
#   'name_prefix': 'Mr.',
#   'country_code': 'BN'},
#  {'id': '88696',
#   'username': 'lawrencedurham',
#   'name': 'Jeremy Griffin',
#   'mail': 'robert84@hotmail.com',
#   'registered': '2015-12-17',
#   'birthdate': '1951-12-30'},
#  {'id': '93935',
#   'username': 'tyler52',
#   'sex': 'F',
#   'registered': '2017-10-03',
#   'birthdate': '1970-03-14',
#   'name_prefix': 'Dr.'},
#  {'id': '3718',
#   'username': 'robert98',
#   'name': 'Emily Powell',
#   'mail': 'timothyatkinson@yahoo.com',
#   'registered': '2009-09-03'},
#  {'id': '14744',
#   'username': 'bassmatthew',
#   'name': 'Raymond Case',
#   'sex': 'M',
#   'country': 'Serbia',
#   'mail': 'ablevins@hotmail.com',
#   'name_prefix': 'Mr.',
#   'country_code': 'RS'},
#  {'id': '14299',
#   'username': 'vjones',
#   'sex': 'M',
#   'mail': 'oberry@gmail.com',
#   'birthdate': '1971-07-10'},
#  {'id': '33147',
#   'username': 'michellelittle',
#   'country': 'Bolivia',
#   'mail': 'matthewgriffith@hotmail.com',
#   'registered': '2016-03-05',
#   'country_code': 'BO'},
#  {'id': '95382',
#   'username': 'romerojason',
#   'sex': 'F',
#   'country': 'Sierra Leone',
#   'registered': '2011-11-23',
#   'country_code': 'SL'},
#  {'id': '49092',
#   'username': 'ldavis',
#   'country': 'Iceland',
#   'birthdate': '1992-09-21',
#   'country_code': 'IS'},
#  {'id': '81924',
# ...
#   'username': 'hernandezchad',
#   'sex': 'F',
#   'registered': '2011-12-31'},
#  {'id': '42105',
#   'username': 'qvega',
#   'name': 'Andrea Robinson',
#   'country': 'Philippines',
#   'mail': 'currydarren@yahoo.com',
#   'birthdate': '2019-07-28',
#   'country_code': 'PH'},
#  {'id': '29509',
#   'username': 'ecombs',
#   'sex': 'F',
#   'registered': '2013-01-04',
#   'name_prefix': 'Mrs.'},
#  {'id': '6636',
#   'username': 'gabriel00',
#   'name': 'Sara Neal',
#   'sex': 'F',
#   'country': 'Micronesia'},
#  {'id': '63510',
#   'username': 'phillipsnancy',
#   'country': 'Chad',
#   'birthdate': '1984-10-22',
#   'country_code': 'TD'},
#  {'id': '65901',
#   'username': 'johnsoncindy',
#   'sex': 'M',
#   'registered': '2015-01-24'},
#  {'id': '96523',
#   'username': 'johnsonsandra',
#   'name': 'Monica Wright',
#   'sex': 'F',
#   'mail': 'johnsonbrittany@hotmail.com',
#   'registered': '2009-05-06',
#   'birthdate': '1969-05-22'},
#  {'id': '20563',
#   'username': 'halexander',
#   'name': 'Max Hall',
#   'sex': 'M',
#   'mail': 'walkermichael@yahoo.com',
#   'registered': '2016-01-30',
#   'birthdate': '1977-06-16',
#   'name_prefix': 'Dr.'},
#  {'id': '99220',
#   'username': 'alimary',
#   'name': 'Natalie Donovan',
#   'registered': '2010-06-27'},
#  {'id': '83864',
#   'username': 'elizabeth76',
#   'sex': 'M',
#   'country': 'Morocco',
#   'mail': 'brennanariana@yahoo.com',
#   'registered': '2014-08-29',
#   'birthdate': '1998-07-17',
#   'name_prefix': 'Mr.',
#   'country_code': 'MA'},
#  {'id': '49862', 'username': 'obrown', 'birthdate': '1972-05-10'},
#  {'id': '15890',
#   'username': 'johnsonkendra',
#   'sex': 'F',
#   'mail': 'milleradam@yahoo.com',
#   'registered': '2008-09-29',
#   'name_prefix': 'Miss'},
#  {'id': '49082',
#   'username': 'snowcynthia',
#   'name': 'Kevin Turner',
#   'mail': 'sophia44@hotmail.com',
#   'registered': '2004-05-21'},
#  {'id': '82664',
#   'username': 'jeffrey76',
#   'sex': 'M',
#   'country': 'Kyrgyz Republic',
#   'mail': 'michelle21@hotmail.com',
#   'registered': '2013-06-29',
#   'name_prefix': 'Dr.'},
#  {'id': '64454',
#   'username': 'tara33',
#   'country': 'Bouvet Island (Bouvetoya)',
#   'mail': 'tespinoza@yahoo.com',
#   'birthdate': '2022-04-09'},
#  {'id': '98899',
#   'username': 'copelandtracy',
#   'name': 'Randall Mercado',
#   'country': 'French Guiana',
#   'country_code': 'GF'},
#  {'id': '47213',
#   'username': 'rebecca10',
#   'sex': 'F',
#   'birthdate': '1996-03-07',
#   'name_prefix': 'Miss'},
#  {'id': '68376',
#   'username': 'villarrealstacey',
#   'name': 'Edward Green',
#   'sex': 'M',
#   'registered': '2006-04-24',
#   'name_prefix': 'Mr.'},
#  {'id': '11137',
#   'username': 'forozco',
#   'sex': 'M',
#   'mail': 'gfry@gmail.com',
#   'registered': '2010-10-08'},
#  {'id': '33335',
#   'username': 'jeffrey10',
#   'country': 'Macao',
#   'registered': '2003-03-30',
#   'birthdate': '2008-08-30',
#   'country_code': 'MO'},
#  {'id': '40268', 'username': 'sabrinagonzalez', 'mail': 'joneserin@gmail.com'},
#  {'id': '21129',
#   'username': 'powelljessica',
#   'sex': 'F',
#   'mail': 'crivera@yahoo.com',
#   'registered': '2002-12-02'},
#  {'id': '41565',
#   'username': 'courtney28',
#   'registered': '2002-02-21',
#   'birthdate': '2010-12-19'},
#  {'id': '50719',
#   'username': 'christopher54',
#   'country': 'Anguilla',
#   'birthdate': '2022-12-08',
#   'country_code': 'AI'},
#  {'id': '86098',
#   'username': 'alexisholmes',
#   'sex': 'F',
#   'country': 'Christmas Island',
#   'birthdate': '1972-04-02',
#   'name_prefix': 'Mrs.',
#   'country_code': 'CX'},
#  {'id': '91694',
#   'username': 'anthonygrimes',
#   'mail': 'davidparker@hotmail.com',
#   'registered': '2002-05-01',
#   'birthdate': '2019-07-17'},
#  {'id': '63444',
#   'username': 'adawson',
#   'name': 'Steve Morris',
#   'sex': 'M',
#   'mail': 'ewilson@yahoo.com',
#   'birthdate': '2002-11-14',
#   'name_prefix': 'Mr.'},
#  {'id': '19653',
#   'username': 'gardneramy',
#   'mail': 'wlogan@gmail.com',
#   'birthdate': '2018-12-30'},
#  {'id': '30283',
#   'username': 'shieldssarah',
#   'name': 'Nathan Pittman',
#   'sex': 'M',
#   'country': 'Antarctica (the territory South of 60 deg S)',
#   'mail': 'parksdaniel@yahoo.com',
#   'registered': '2016-10-11',
#   'name_prefix': 'Mr.'},
#  {'id': '92708',
#   'username': 'bgonzalez',
#   'name': 'Karen Burgess',
#   'sex': 'F',
#   'country': 'Albania',
#   'country_code': 'AL'},
#  {'id': '98452', 'username': 'brianking', 'mail': 'areynolds@hotmail.com'},
#  {'id': '37279',
#   'username': 'martinmichele',
#   'name': 'Jill Johnson',
#   'country': 'Denmark',
#   'mail': 'hillmichael@gmail.com',
#   'birthdate': '2009-12-15',
#   'country_code': 'DK'},
#  {'id': '2483',
#   'username': 'reneelee',
#   'name': 'Mrs. Amy Adkins',
#   'birthdate': '1987-11-24'},
#  {'id': '27352', 'username': 'cherylbarker', 'registered': '2004-01-21'},
#  {'id': '28439',
#   'username': 'paul14',
#   'name': 'Mark Woods',
#   'sex': 'M',
#   'mail': 'rlewis@hotmail.com',
#   'registered': '2012-05-15'},
#  {'id': '89838',
#   'username': 'wilsonebony',
#   'mail': 'harrellnicole@gmail.com',
#   'birthdate': '1962-02-12'},
#  {'id': '20229',
#   'username': 'tmorrison',
#   'name': 'Vanessa Stevens',
#   'sex': 'F',
#   'mail': 'thompsonrobin@yahoo.com',
#   'name_prefix': 'Dr.'},
#  {'id': '5102',
#   'username': 'jessicasmith',
#   'sex': 'F',
#   'mail': 'deannicole@gmail.com',
#   'registered': '2009-06-11',
#   'name_prefix': 'Dr.'},
#  {'id': '86577',
#   'username': 'fferguson',
#   'name': 'David Williams',
#   'registered': '2018-07-10'},
#  {'id': '37996',
#   'username': 'codysanchez',
#   'sex': 'F',
#   'country': 'Iceland',
#   'registered': '2002-02-01',
#   'name_prefix': 'Mrs.',
#   'country_code': 'IS'},
#  {'id': '76616',
#   'username': 'ramospatricia',
#   'sex': 'F',
#   'registered': '2019-06-21'},
#  {'id': '83409',
#   'username': 'sarah96',
#   'name': 'Christopher Espinoza',
#   'sex': 'M',
#   'registered': '2014-07-07',
#   'name_prefix': 'Mr.'},
#  {'id': '53151',
#   'username': 'michaeldougherty',
#   'name': 'Jonathan Richard',
#   'sex': 'M',
#   'mail': 'greenescott@gmail.com',
#   'birthdate': '1979-11-01'},
#  {'id': '91357',
#   'username': 'chapmankimberly',
#   'sex': 'F',
#   'country': 'Antigua and Barbuda',
#   'registered': '2001-06-26',
#   'birthdate': '2017-06-04',
#   'country_code': 'AG'},
#  {'id': '31450', 'username': 'eturner', 'name': 'Michael Russo', 'sex': 'M'},
#  {'id': '62674',
#   'username': 'sandrakent',
#   'name': 'Matthew Fisher',
#   'sex': 'M',
#   'country': 'Cayman Islands',
#   'registered': '2006-10-15',
#   'birthdate': '2010-08-29',
#   'name_prefix': 'Mr.',
#   'country_code': 'KY'},
#  {'id': '77752',
#   'username': 'oharris',
#   'name': 'Joshua Rowland',
#   'mail': 'rachel36@yahoo.com',
#   'registered': '2014-10-05',
#   'birthdate': '1963-02-25'},
#  {'id': '96095',
#   'username': 'thopkins',
#   'country': 'Chile',
#   'birthdate': '1962-10-11',
#   'country_code': 'CL'},
#  {'id': '40920',
#   'username': 'amanda19',
#   'sex': 'F',
#   'country': 'Saint Lucia',
#   'country_code': 'LC'},
#  {'id': '27044',
#   'username': 'john52',
#   'sex': 'M',
#   'mail': 'aaron73@gmail.com',
#   'registered': '2008-08-26'},
#  {'id': '79839',
#   'username': 'jesse05',
#   'country': 'New Caledonia',
#   'mail': 'stephen80@gmail.com',
#   'country_code': 'NC'},
#  {'id': '76202',
#   'username': 'lisa22',
#   'sex': 'F',
#   'country': 'Russian Federation',
#   'mail': 'ularson@hotmail.com',
#   'registered': '2019-09-22',
#   'birthdate': '2019-11-01',
#   'name_prefix': 'Mrs.'},
#  {'id': '70269',
#   'username': 'stephanieclark',
#   'name': 'Clayton Holland',
#   'mail': 'christinathompson@yahoo.com',
#   'registered': '2019-01-03',
#   'birthdate': '1995-06-21'},
#  {'id': '72004',
#   'username': 'qthomas',
#   'name': 'Jessica Smith',
#   'sex': 'F',
#   'mail': 'morganwang@hotmail.com'},
#  {'id': '62735', 'username': 'julie50', 'name': 'Hannah Mitchell'},
#  {'id': '25826',
#   'username': 'matthew60',
#   'name': 'Kathy Moran',
#   'country': 'Greece',
#   'birthdate': '1965-04-06',
#   'country_code': 'GR'},
#  {'id': '44786',
#   'username': 'vlam',
#   'name': 'Kurt Owens',
#   'sex': 'M',
#   'country': 'Argentina',
#   'mail': 'christianwendy@yahoo.com',
#   'registered': '2019-09-29',
#   'country_code': 'AR'},
#  {'id': '93940',
#   'username': 'jessica75',
#   'name': 'Mariah French',
#   'sex': 'F',
#   'mail': 'rodriguezsamantha@yahoo.com',
#   'registered': '2003-12-31',
#   'name_prefix': 'Mrs.'},
#  {'id': '56415',
#   'username': 'justin27',
#   'name': 'Corey Clark',
#   'registered': '2012-06-04'},
#  {'id': '88420',
#   'username': 'kwelch',
#   'name': 'Lori Gomez',
#   'sex': 'F',
#   'country': 'Guyana',
#   'mail': 'qmccarthy@yahoo.com',
#   'registered': '2009-01-05',
#   'birthdate': '1955-02-15',
#   'name_prefix': 'Mrs.',
#   'country_code': 'GY'},
#  {'id': '61344', 'username': 'richardwhite', 'name': 'William Gross'},
#  {'id': '67754',
#   'username': 'thompsonmelissa',
#   'name': 'Kristin Vaughn',
#   'country': 'New Caledonia',
#   'registered': '2002-09-15',
#   'country_code': 'NC'},
#  {'id': '95843',
#   'username': 'katrinataylor',
#   'country': 'Colombia',
#   'country_code': 'CO'},
#  {'id': '1187', 'username': 'parmstrong', 'registered': '2011-07-01'},
#  {'id': '50744',
#   'username': 'caitlinthomas',
#   'sex': 'M',
#   'mail': 'paulmartin@hotmail.com',
#   'birthdate': '1968-04-24',
#   'name_prefix': 'Dr.'},
#  {'id': '49441',
#   'username': 'alvarezcheryl',
#   'name': 'Benjamin Cole',
#   'birthdate': '1975-04-22'},
#  {'id': '4532',
#   'username': 'melissaperez',
#   'name': 'Mark Salazar DDS',
#   'registered': '2002-04-28',
#   'birthdate': '2012-05-30'},
#  {'id': '74713',
#   'username': 'juanpearson',
#   'mail': 'buckjessica@yahoo.com',
#   'birthdate': '1999-10-26'},
#  {'id': '30837',
#   'username': 'joseph88',
#   'sex': 'F',
#   'birthdate': '1963-01-27'},
#  {'id': '59354',
#   'username': 'paul00',
#   'name': 'Christopher Baker',
#   'country': 'Kiribati',
#   'mail': 'patriciayoder@yahoo.com',
#   'registered': '2002-01-16',
#   'birthdate': '2017-10-18',
#   'country_code': 'KI'},
#  {'id': '359',
#   'username': 'stevenlyons',
#   'sex': 'F',
#   'country': 'Egypt',
#   'mail': 'shelly00@hotmail.com',
#   'registered': '2010-04-26',
#   'name_prefix': 'Mrs.',
#   'country_code': 'EG'},
#  {'id': '39743',
#   'username': 'uparks',
#   'name': 'Joseph Johnson',
#   'sex': 'M',
#   'country': 'Timor-Leste',
#   'birthdate': '1951-02-14',
#   'name_prefix': 'Dr.',
#   'country_code': 'TL'},
#  {'id': '42456',
#   'username': 'andrewssarah',
#   'country': 'British Virgin Islands',
#   'registered': '2015-08-26'},
#  {'id': '62244',
#   'username': 'claudia86',
#   'name': 'Shawna Lopez',
#   'country': 'Philippines',
#   'birthdate': '1955-05-29',
#   'country_code': 'PH'},
#  {'id': '66676',
#   'username': 'librian',
#   'name': 'Joshua Turner',
#   'sex': 'M',
#   'country': 'Equatorial Guinea',
#   'mail': 'zpeters@gmail.com',
#   'registered': '2018-07-24',
#   'name_prefix': 'Mr.',
#   'country_code': 'GQ'},
#  {'id': '79033',
#   'username': 'byrdmichaela',
#   'name': 'William Glenn',
#   'country': 'Myanmar',
#   'mail': 'sarahespinoza@hotmail.com',
#   'country_code': 'MM'},
#  {'id': '56587', 'username': 'drewlivingston', 'birthdate': '1964-05-01'},
#  {'id': '8475',
#   'username': 'simpsontimothy',
#   'name': 'Jennifer Flores',
#   'birthdate': '1993-02-05'},
#  {'id': '43511',
#   'username': 'madeline21',
#   'name': 'Nicholas Foster',
#   'country': 'Grenada',
#   'registered': '2014-03-02',
#   'country_code': 'GD'},
#  {'id': '99359', 'username': 'christophermclean', 'registered': '2010-08-18'},
#  {'id': '16106',
#   'username': 'linda32',
#   'name': 'Mason Mejia',
#   'mail': 'ellen30@yahoo.com',
#   'registered': '2017-09-23'},
#  {'id': '14365',
#   'username': 'kcooper',
#   'name': 'Michelle Knight',
#   'country': 'Bahamas',
#   'registered': '2007-03-10',
#   'country_code': 'BS'},
#  {'id': '66396',
#   'username': 'hoganbenjamin',
#   'name': 'Karen Chen',
#   'country': 'Argentina',
#   'country_code': 'AR'},
#  {'id': '70703',
#   'username': 'newtonkelly',
#   'country': 'Nicaragua',
#   'mail': 'xsmith@gmail.com',
#   'birthdate': '2004-10-12',
#   'country_code': 'NI'},
#  {'id': '73649',
#   'username': 'mhuff',
#   'name': 'Tina Hoffman',
#   'sex': 'F',
#   'country': 'Guinea',
#   'name_prefix': 'Dr.',
#   'country_code': 'GN'},
#  {'id': '91930',
#   'username': 'bradfordlaurie',
#   'sex': 'F',
#   'country': 'Liberia',
#   'mail': 'fmercado@hotmail.com',
#   'name_prefix': 'Mrs.',
#   'country_code': 'LR'},
#  {'id': '23632',
#   'username': 'jonesamanda',
#   'sex': 'F',
#   'country': 'Bahrain',
#   'birthdate': '1954-08-01',
#   'name_prefix': 'Dr.',
#   'country_code': 'BH'},
#  {'id': '71363',
#   'username': 'mjones',
#   'name': 'Sarah Hart',
#   'sex': 'F',
#   'country': 'Philippines',
#   'mail': 'danny04@yahoo.com',
#   'registered': '2019-08-18',
#   'name_prefix': 'Dr.',
#   'country_code': 'PH'},
#  {'id': '34586',
#   'username': 'nguyendeanna',
#   'country': 'Romania',
#   'birthdate': '1977-12-08',
#   'country_code': 'RO'},
#  {'id': '59757',
#   'username': 'sandrahernandez',
#   'name': 'Lisa Sandoval',
#   'sex': 'F',
#   'country': 'Aruba',
#   'mail': 'phillipgonzales@yahoo.com',
#   'registered': '2012-01-14',
#   'name_prefix': 'Mrs.',
#   'country_code': 'AW'},
#  {'id': '19560',
#   'username': 'jennifer65',
#   'sex': 'M',
#   'country': 'Argentina',
#   'name_prefix': 'Mr.',
#   'country_code': 'AR'},
#  {'id': '75885',
#   'username': 'kelly95',
#   'name': 'Mary Guerrero',
#   'mail': 'gonzalezapril@hotmail.com',
#   'registered': '2012-08-18',
#   'birthdate': '1979-07-21'},
#  {'id': '4449', 'username': 'brianday', 'sex': 'M', 'name_prefix': 'Mr.'},
#  {'id': '89964',
#   'username': 'christopher83',
#   'name': 'Robert Stewart',
#   'sex': 'M',
#   'country': 'Nigeria',
#   'registered': '2006-05-01',
#   'name_prefix': 'Mr.',
#   'country_code': 'NG'},
#  {'id': '94486', 'username': 'vkelly', 'birthdate': '2013-06-11'},
#  {'id': '78508', 'username': 'jarnold', 'name': 'Michael Lopez', 'sex': 'M'},
#  {'id': '20160',
#   'username': 'rhondayoung',
#   'country': 'Trinidad and Tobago',
#   'registered': '2009-11-23',
#   'country_code': 'TT'},
#  {'id': '31698',
#   'username': 'bryantdarrell',
#   'name': 'Robin Reese',
#   'sex': 'F',
#   'country': 'Libyan Arab Jamahiriya',
#   'registered': '2019-04-28',
#   'name_prefix': 'Mrs.',
#   'country_code': 'LY'},
#  {'id': '3655',
#   'username': 'rivasmark',
#   'mail': 'hannah83@gmail.com',
#   'registered': '2002-03-23'},
#  {'id': '59605',
#   'username': 'toddwillie',
#   'name': 'Joseph Ortega',
#   'country': 'Bouvet Island (Bouvetoya)',
#   'registered': '2007-08-25'},
#  {'id': '58332',
#   'username': 'wolfeanne',
#   'name': 'Denise Parker',
#   'sex': 'F',
#   'name_prefix': 'Mrs.'},
#  {'id': '68150',
#   'username': 'yolandareynolds',
#   'name': 'Laura Ochoa',
#   'mail': 'kbradley@gmail.com',
#   'registered': '2007-05-11'},
#  {'id': '68843',
#   'username': 'ihenry',
#   'name': 'Daniel Mcmillan',
#   'sex': 'M',
#   'country': 'Lebanon',
#   'registered': '2003-01-09',
#   'birthdate': '1979-02-22',
#   'name_prefix': 'Mr.',
#   'country_code': 'LB'},
#  {'id': '44139',
#   'username': 'jamesandrew',
#   'name': 'David Vasquez',
#   'sex': 'M',
#   'registered': '2013-10-29',
#   'name_prefix': 'Dr.'},
#  {'id': '88999',
#   'username': 'peter02',
#   'sex': 'F',
#   'mail': 'wkelley@hotmail.com',
#   'registered': '2005-05-21',
#   'birthdate': '1964-11-13'},
#  {'id': '45298',
#   'username': 'ohall',
#   'name': 'Wanda Salazar',
#   'country': 'Madagascar',
#   'registered': '2002-02-07',
#   'birthdate': '1976-08-10',
#   'country_code': 'MG'},
#  {'id': '74911',
#   'username': 'justin75',
#   'name': 'Christopher Perez',
#   'sex': 'M',
#   'country': 'Libyan Arab Jamahiriya',
#   'mail': 'abigail25@hotmail.com',
#   'name_prefix': 'Dr.',
#   'country_code': 'LY'},
#  {'id': '90126',
#   'username': 'dalton04',
#   'name': 'Mary Stout',
#   'mail': 'cbates@yahoo.com',
#   'birthdate': '1995-04-23'},
#  {'id': '65799',
#   'username': 'jose11',
#   'name': 'Paula Yang',
#   'sex': 'F',
#   'country': 'Benin',
#   'mail': 'martinezdevin@gmail.com',
#   'country_code': 'BJ'},
#  {'id': '61296',
#   'username': 'micheleharris',
#   'name': 'Janice Sullivan',
#   'registered': '2001-03-19',
#   'birthdate': '2004-02-13'},
#  {'id': '60763', 'username': 'areed', 'mail': 'ryan75@hotmail.com'},
#  {'id': '88602',
#   'username': 'jreynolds',
#   'name': 'David Dixon',
#   'sex': 'M',
#   'registered': '2010-08-02'},
#  {'id': '73359',
#   'username': 'terri08',
#   'name': 'Edward Allen',
#   'mail': 'mstafford@gmail.com'},
#  {'id': '15625',
#   'username': 'toddamanda',
#   'name': 'Stephanie Thomas',
#   'country': 'Afghanistan',
#   'mail': 'william49@yahoo.com',
#   'country_code': 'AF'},
#  ...]

# %% [markdown]
# 2\. Измерьте время выполнения функции из задания 1 на всех файлах из каталога `reviewers_full`. Ускорьте время выполнения, используя `dask.delayed`.

# %%
# %%time
files = [f"reviewers_full/reviewers_full_{i}.xml" for i in np.arange(0, 20)]

for file in files:
    read_xml(file)
# Out:
# CPU times: total: 5min 38s
# Wall time: 5min 38s

# %%
read_xml_delayed = dask.delayed(read_xml)

# %%
r1 = [read_xml_delayed(file) for file in files]

# %%
# %time res = dask.compute(r1, scheduler="multiprocessing")
# Out:
# CPU times: total: 719 ms
# Wall time: 1min 42s

# %% [markdown]
# 3\. Задекорируйте функцию из задания 1 при помощи `dask.delayed` и создайте список `reviewers`, состоящий из 5 объектов `delayed` (по одному объекту на файл). Из списка объектов `delayed`, создайте `dask.bag` при помощи метода `db.from_delayed`. Добавьте ключ `birth_year`, в котором хранится год рождения человека. Оставьте в выборке только тех людей, которые __наверняка__ моложе 1980 года. Преобразуйте поле `id` к целому типу.

# %%
def add_birth_year(x):
    if x.get('birthdate'):
        x['birth_year'] = int(x['birthdate'][:4])
    return x

def make_id_int(x):
    x['id'] = int(x['id'])
    return x

read_xml_delayed = dask.delayed(read_xml)
reviewers = [read_xml_delayed(file) for file in files[:5]]
bag = db.from_delayed(reviewers)
bag = bag.map(add_birth_year)
bag = bag.filter(lambda x: x.get('birth_year')).filter(lambda x: x.get('birth_year') > 1980)
bag = bag.map(make_id_int)
bag.take(2)
# Out:
# ({'id': 68591,
#   'username': 'daniellegomez',
#   'sex': 'F',
#   'country': 'Germany',
#   'birthdate': '2005-03-06',
#   'name_prefix': 'Dr.',
#   'country_code': 'DE',
#   'birth_year': 2005},
#  {'id': 43614,
#   'username': 'jeffreynelson',
#   'sex': 'F',
#   'country': 'Aruba',
#   'mail': 'laura77@hotmail.com',
#   'registered': '2019-11-19',
#   'birthdate': '1994-10-10',
#   'country_code': 'AW',
#   'birth_year': 1994})
